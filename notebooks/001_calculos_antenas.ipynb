# %%
import numpy as np

# %%
np.sqrt(400 ** 2 + 100 ** 2)
# Out:
# np.float64(412.31056256176606)

# %% [markdown]
# ec. Friis
#
# $$P_r = P_tG_tG_r\left(\frac{\lambda}{4\pi R}\right)²$$
#
# $_r$ receptor
#
# $_t$ transmisor
#
# $P$ potencia [W]
#
# $G$ ganancia
#
# $\lambda$ longitud de onda [m]
#
# $R$ distancia entre antenas

# %% [markdown]
# escala logarítmica
#
# dBm = decibel milliwatts
#
# $$P_{\text{dBm}}=10\log{\left(\frac{P}{1\ \text{mW}}\right)}$$
#
# $$P_{r,\text{dBm}} = P_{t,\text{dBm}} + G_{t,\text{dBi}} + G_{r,\text{dBi}} + 20\text{dB}\log{\left(\frac{\lambda}{4\pi R}\right)}$$
#
# $$P_{r,\text{dBm}} = \text{cte.} - 20\text{dB}\log{\left(R\right)}$$
#
# $R=500\ \text{m}$
#
# $f=2.4\times10^{9}\ \text{Hz}$
#
# $c=\lambda f$
#
# $\lambda = \frac{c}{f}$
#
# $\lambda = 0.1249135242\ \text{m}$
#
# $\text{EIRP}_{\text{dBm}}=P_{t,\text{dBm}} + G_{t,\text{dBi}}\leq20\text{dBm}$
#
# $P_{t,\text{dBm}}=18$
#
# $G_{t,\text{dBi}}=2.2$
#
# $\eta=0.62$

# %% [markdown]
# $$P_{r,\text{dBm}} - G_{r,\text{dBi}} = 20\text{dBm} + 20\text{dB}\log{\left(\frac{0.1249135242\ \text{m}}{4\pi\times500\ \text{m}}\right)}$$
#
# $$P_{r,\text{dBm}} - G_{r,\text{dBi}} = -74.03140814051802\text{dBm}$$

# %%
20 + 20 * np.log10(0.1249135242 / (4 * np.pi * 500))
# Out:
# np.float64(-74.03140814051802)

# %%
np.rad2deg(np.tan(40/11))
# Out:
# np.float64(30.912916238600808)

# %%
10 * np.log10(50000)
# Out:
# np.float64(46.98970004336019)
